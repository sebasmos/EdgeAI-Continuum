# %%
for _ in range(20):
    # !python model_train.py --name_experiment "Mac"
# Out:
# /Users/sebasmos/anaconda3/envs/api/lib/python3.10/site-packages/dataclay/config.py:181: UserWarning: directory "/run/secrets" does not exist
#   settings = Settings()
# INFO:root:Using device: cpu
# Saving in... results/Mac/20250314-155703
# INFO:root:Device: cpu
# INFO:root:Dataset: /Users/sebasmos/Desktop/ucd_fun_horizon_icos_papers/Dataclay_paper/AIoffload/dataset/node_3_utilisation_sample_dataset.csv
# INFO:root:Collecting raw data from local device
# INFO:root:Preparing dataset for PyTorch model
# supervised_train_data:  (1585, 14)
# X_train_np:  (1585, 12)
# X_train (reshaped):  (1585, 6, 2)
# INFO:root:LSTMModel(
#   (lstm): LSTM(2, 64, batch_first=True)
#   (fc): Linear(in_features=64, out_features=2, bias=True)
# )
# model:  fp32  	 Size (KB): 72.362
# /Users/sebasmos/anaconda3/envs/api/lib/python3.10/site-packages/dataclay/config.py:181: UserWarning: directory "/run/secrets" does not exist
#   settings = Settings()
# INFO:root:Epoch [1/100], Train Loss: 0.1718
# ...

# %%
for _ in range(20):
    # !python model_train.py --name_experiment "OrangePI"
